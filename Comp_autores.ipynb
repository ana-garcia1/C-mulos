# %% [markdown]
# <a href="https://colab.research.google.com/github/ana-garcia1/C-mulos/blob/main/Comp_autores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
labels = ('Alessi 18',
'Archinal 1',
'Berkeley 82',
'ESO 312-04',
'ESO 430-09',
'ESO 435-48',
'ESO 445-74',
'ESO 518-03',
'NGC 6204',
'vdBH 92')

# %%
#mis valores:
Garcia = ( 2.00,
0.010,
0.10,
0.10,
0.050,
2.00,
5.00,
2.50,
0.225,
3.0)

Garcia_err_inf = (1,
              0.003,
              0.05,
              0.05,
              0.02,
              0.7,
              2,
              0.5,
              0.025,
              1)

Garcia_err_sup = (1,
              0.03,
              0.1,
              0.05,
              0.05,
              2,
              3,
              1.5,
              0.025,
              2)

# %%
Garcia_yr = []
for i in range(len(Garcia)):
    Garcia_yr.append( Garcia[i] * 1000000000)

Garcia_err_inf_yr = []
for i in range(len(Garcia)):
    Garcia_err_inf_yr.append( Garcia_err_inf[i] * 1000000000)

Garcia_err_sup_yr = []
for i in range(len(Garcia)):
    Garcia_err_sup_yr.append( Garcia_err_sup[i] * 1000000000)

# %%
fisa_rangos = [(0.75, 1.25), (0.005, 0.01), (0.045, 0.35), (0.2, 0.35), (0.027, 0.035), (1.75, 2.25), (1.75, 2.25), (1.75, 2.25), (0.2, 0.35), (0.75, 1.25)]
fisa_rangos_yr = []
for i in range(len(fisa_rangos)):
    fisa_rango_lim = []
    for j in range(len(fisa_rangos[i])):
        fisa_rango_lim.append(fisa_rangos[i][j]*1000000000)
    fisa_rangos_yr.append(fisa_rango_lim)

# Extraer alturas y posiciones
fisa_mins = [r[0] for r in fisa_rangos_yr]
fisa_alturas = [r[1] - r[0] for r in fisa_rangos_yr]

# %%
Kharchenko = ( 1.00,
0.10,
0.10,
0.20,
0.30,
0.50,
3.00,
1.00,
0.10,
0.80)

Kharchenko_err_inf = (0.20,
                      0.04,
                      0.05,
                      0.04,
                      0.07,
                      0.10,
                      0.70,
                      0.30,
                      0.04,
                      0.20)

Kharchenko_err_sup = (0.30,
                      0.08,
                      0.09,
                      0.05,
                      0.08,
                      0.10,
                      0.80,
                      0.40,
                      0.08,
                      0.20)

# %%
Kharchenko_yr = []
for i in range(len(Kharchenko)):
    Kharchenko_yr.append( Kharchenko[i] * 1000000000)

Kharchenko_err_inf_yr = []
for i in range(len(Kharchenko)):
    Kharchenko_err_inf_yr.append( Kharchenko_err_inf[i] * 1000000000)

Kharchenko_err_sup_yr = []
for i in range(len(Kharchenko)):
    Kharchenko_err_sup_yr.append( Kharchenko_err_sup[i] * 1000000000)

# %%
Dias = ( 0.7,
        0.010,
        0.20,
        0.10,
        0,
        0,
        0,
        2,
        0.1,
        0.03)

Dias_err_inf = (0.5,
                0.003,
                0.09,
                0.09,
                0,
                0,
                0,
                0.3,
                0.04,
                0.02)

Dias_err_sup = (3,
                0.004,
                0.2,
                0.5,
                0,
                0,
                0,
                0.3,
                0.07,
                0.04)

# %%
Dias_yr = []
for i in range(len(Dias)):
    Dias_yr.append( Dias[i] * 1000000000)

Dias_err_inf_yr = []
for i in range(len(Dias)):
    Dias_err_inf_yr.append( Dias_err_inf[i] * 1000000000)

Dias_err_sup_yr = []
for i in range(len(Dias)):
    Dias_err_sup_yr.append( Dias_err_sup[i] * 1000000000)

# %%
CG= ( 0.005,
     0.10,
     0,
     0.05,
     0,
     0,
     0,
     1,
     0.09,
     0.2)

CG_err_inf = (0.002,
              0.04,
              0,
              0.02,
              0,
              0,
              0,
              0.4,
              0.03,
              0.06)


CG_err_sup = (0.003,
              0.06,
              0,
              0.030,
              0,
              0,
              0,
              0.6,
              0.06,
              0.09)

# %%
CG_yr = []
for i in range(len(CG)):
    CG_yr.append(CG[i] * 1000000000)

CG_err_inf_yr = []
for i in range(len(CG)):
    CG_err_inf_yr.append(CG_err_inf[i] * 1000000000)

CG_err_sup_yr = []
for i in range(len(CG)):
    CG_err_sup_yr.append(CG_err_sup[i] * 1000000000)

# %%
plt.figure(figsize=(15,6))


plt.subplot()

plt.grid(color='gray', linestyle='--', linewidth=0.8, alpha= 0.5)

x = np.arange(0, 10)



#isócronas
plt.scatter(x+0.02, Garcia_yr, marker='*', c='royalblue', s = 200, alpha=0.8, label='Este trabajo')
plt.errorbar(x+0.02, Garcia_yr, yerr=(Garcia_err_inf_yr, Garcia_err_sup_yr), fmt='.', c='royalblue', elinewidth=2, capsize=5, capthick=2, alpha=0.8)

#fisa
plt.bar(x, fisa_alturas, bottom=fisa_mins, width=0.15, alpha=0.7, color='blueviolet', label='FISA')

# Obtener el objeto de los ejes actuales
ax = plt.gca()

# Cambiar el color de las etiquetas de los ejes (ticks)
ax.tick_params(axis='x', labelsize=14, rotation=15)  # Color de las etiquetas en el eje X
ax.tick_params(axis='y', labelsize=14)  # Color de las etiquetas en el eje Y


# Cambiar el color de las etiquetas de los ejes (nombres de los ejes X e Y)
ax.set_xlabel('', fontsize=14)
ax.set_ylabel('Nombre del Eje Y')


for i in range(len(labels)):

    if Kharchenko[i] != 0:
        plt.scatter(x[i]-0.02, Kharchenko_yr[i], marker='s', c='gold', s = 100, label='Kharchenko')
        plt.errorbar(x[i]-0.02, Kharchenko_yr[i], yerr=[[Kharchenko_err_inf_yr[i]], [Kharchenko_err_sup_yr[i]]], fmt='.', c='gold', elinewidth=2, capsize=5, capthick=2)

    if Dias[i] != 0:
        plt.scatter(x[i]+0.07, Dias_yr[i], marker='^', c='orangered', s = 100, alpha=0.8)
        plt.errorbar(x[i]+0.07, Dias_yr[i], yerr=[[Dias_err_inf_yr[i]], [Dias_err_sup_yr[i]]], fmt='.', c='orangered', elinewidth=2, capsize=5, capthick=2, alpha=0.8)

    if CG[i] != 0:
        plt.scatter(x[i]-0.07, CG_yr[i], marker='X', c='limegreen', s = 100, alpha=0.8)
        plt.errorbar(x[i]-0.07, CG_yr[i], yerr=[[CG_err_inf_yr[i]], [CG_err_sup_yr[i]]], fmt='.', c='limegreen', elinewidth=2, capsize=5, capthick=2, alpha=0.8)

plt.xticks(x, labels)
plt.ylabel('Edad [años]', fontsize=14)

from matplotlib.lines import Line2D

# Crear líneas ficticias para la leyenda
custom_lines = [
    Line2D([0], [0], marker='*', c='royalblue', alpha=0.8, linestyle='None'),  # Línea 1
    Line2D([0], [0],  marker='s', alpha=0.7, color='blueviolet', linestyle='None') ,   # Línea 2
    Line2D([0],[0], marker='o', c='gold', linestyle='None'),
    Line2D([0],[0], marker='^', c='orangered', alpha=0.8, linestyle='None'),
    Line2D([0],[0], marker='X', c='limegreen', alpha=0.8, linestyle='None')
]

plt.legend(custom_lines, ['Isócronas', 'FISA', 'K13', 'D21', 'CG20'], markerscale=2, ncols=5, fontsize=14, bbox_to_anchor=(0.5, -0.2), loc='upper center', borderaxespad=0.)

plt.yscale('log')

plt.savefig('comp_autores.png', bbox_inches='tight')

# %%
plt.legend?
# Out:
# Signature: plt.legend(*args, **kwargs) -> 'Legend'
# Docstring:
# Place a legend on the Axes.
#
# Call signatures::
#
#     legend()
#     legend(handles, labels)
#     legend(handles=handles)
#     legend(labels)
#
# The call signatures correspond to the following different ways to use
# this method:
#
# **1. Automatic detection of elements to be shown in the legend**
#
# The elements to be added to the legend are automatically determined,
# when you do not pass in any extra arguments.
#
# In this case, the labels are taken from the artist. You can specify
# them either at artist creation or by calling the
# :meth:`~.Artist.set_label` method on the artist::
#
#     ax.plot([1, 2, 3], label='Inline label')
#     ax.legend()
#
# or::
#
#     line, = ax.plot([1, 2, 3])
#     line.set_label('Label via method')
#     ax.legend()
#
# .. note::
#     Specific artists can be excluded from the automatic legend element
#     selection by using a label starting with an underscore, "_".
# ...

# %%
plt.figure(figsize=(15,5), facecolor='#1e1f24ff')
plt.style.use('dark_background')

plt.subplot(facecolor='#1e1f24ff')

plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha= 0.1)

plt.scatter(labels, Garcia, marker='*', c='cornflowerblue', s = 500, alpha=0.4, label='Este trabajo')
plt.errorbar(labels, Garcia, yerr=(Garcia_err_inf, Garcia_err_sup), fmt='.', c='cornflowerblue', capsize=5, alpha=0.8)

x = np.arange(0, 10)

for i in range(len(labels)):

    if Kharchenko[i] != 0:
        plt.scatter(x[i]-0.15, Kharchenko[i], marker='s', c='gold', s = 200, alpha=0.4, label='Kharchenko')
        plt.errorbar(x[i]-0.15, Kharchenko[i], yerr=[[Kharchenko_err_inf[i]], [Kharchenko_err_sup[i]]], fmt='.', c='gold', capsize=5, alpha=0.8)

    if Dias[i] != 0:
        plt.scatter(x[i]+0.1, Dias[i], marker='^', c='tomato', s = 200, alpha=0.4)
        plt.errorbar(x[i]+0.1, Dias[i], yerr=[[Dias_err_inf[i]], [Dias_err_sup[i]]], fmt='.', c='tomato', capsize=5, alpha=0.8)

    if CG[i] != 0:
        plt.scatter(x[i]-0.1, CG[i], marker='X', c='springgreen', s = 200, alpha=0.4)
        plt.errorbar(x[i]-0.1, CG[i], yerr=[[CG_err_inf[i]], [CG_err_sup[i]]], fmt='.', c='springgreen', capsize=5, alpha=0.8)


plt.ylabel('Edad [10⁹]')
plt.legend(['Este trabajo', 'Kharchenko', 'Dias', 'Cantat-Gaudin'], markerscale=0.7, ncols=2, facecolor='#1e1f24ff')

# %%
plt.legend?
# Out:
# Signature: plt.legend(*args, **kwargs) -> 'Legend'
# Docstring:
# Place a legend on the Axes.
#
# Call signatures::
#
#     legend()
#     legend(handles, labels)
#     legend(handles=handles)
#     legend(labels)
#
# The call signatures correspond to the following different ways to use
# this method:
#
# **1. Automatic detection of elements to be shown in the legend**
#
# The elements to be added to the legend are automatically determined,
# when you do not pass in any extra arguments.
#
# In this case, the labels are taken from the artist. You can specify
# them either at artist creation or by calling the
# :meth:`~.Artist.set_label` method on the artist::
#
#     ax.plot([1, 2, 3], label='Inline label')
#     ax.legend()
#
# or::
#
#     line, = ax.plot([1, 2, 3])
#     line.set_label('Label via method')
#     ax.legend()
#
# .. note::
#     Specific artists can be excluded from the automatic legend element
#     selection by using a label starting with an underscore, "_".
# ...
